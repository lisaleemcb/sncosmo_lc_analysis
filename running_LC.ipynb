# %%
# %matplotlib inline

import os
import numpy as np
from numpy.random import normal, uniform
import collections
import pandas as pd
from astropy.table import Table

import triangle
import sncosmo
import simulate_lsst as sl
import lc

# %%
sncosmo.version
# Out:
# <module 'sncosmo.version' from '/Users/lisaleemcb/.local/lib/python2.7/site-packages/sncosmo-1.2.dev551-py2.7-macosx-10.5-x86_64.egg/sncosmo/version.pyc'>

# %%
simlibfilename = 'Enigma_1189.SIMLIB.DEEP.FirstYear'
sl.getlsstbandpassobjs()
meta, obstables = sncosmo.read_snana_simlib(simlibfilename)
meta2, obstables2 = sncosmo.read_snana_simlib('LSST_band.simlib')

# %%
obstables.keys(), obstables2.keys()
# Out:
# ([744, 2786, 1427, 2412, 290], [519, 1427])

# %%
# initialize model
source = sncosmo.get_source('salt2-extended')
dust = sncosmo.CCM89Dust()
model_noext = sncosmo.Model(source=source)

model_hostext = sncosmo.Model(source=source,
                      effects=[dust, dust],
                      effect_names=['host', 'mw'],
                      effect_frames=['rest', 'obs'])

waves = np.arange(200.,1000.,10.0)
mabs = -19.0   # use abs magnitude to set value of x0
redshift = .3
t0 = 49370.0
#x0 = 0.0      # uncomment to set x0 manually
x1 = .5
c = 0.1
hostebv = 0.05

# create params list needed for realize_lc()
params_noext = {'z':redshift, 't0': t0, 'x1': x1, 'c': c}
params_hostext = {'z':redshift, 't0': t0, 'x1': x1, 'c': c, 'hostebv': hostebv}
vparams = ['t0', 'x0', 'x1', 'c']

# set model parameters
model_noext.set(**params_noext)
model_hostext.set(**params_hostext)

model_noext.set_source_peakabsmag(mabs, 'bessellb', 'ab')
model_hostext.set_source_peakabsmag(mabs, 'bessellb', 'ab')

x0 = model_noext.get('x0')
params_noext['x0'] = x0

# technically the same as for noext, explicitly repeated for transparency
x0 = model_hostext.get('x0')
params_hostext['x0'] = x0

print params_noext, params_hostext
print model_noext
print model_hostext
# Out:
# {'x1': 0.5, 'z': 0.3, 'x0': 2.55194197621852e-05, 'c': 0.1, 't0': 49370.0} {'c': 0.1, 'z': 0.3, 't0': 49370.0, 'hostebv': 0.05, 'x0': 2.55194197621852e-05, 'x1': 0.5}
# <Model at 0x1094ffb10>
# source:
#   class      : SALT2Source
#   name       : 'salt2-extended'
#   version    : 1.0
#   phases     : [-20, .., 50] days
#   wavelengths: [300, .., 18000] Angstroms
# parameters:
#   z  = 0.29999999999999999
#   t0 = 49370.0
#   x0 = 2.55194197621852e-05
#   x1 = 0.5
#   c  = 0.10000000000000001
# <Model at 0x1094ffb90>
# source:
#   class      : SALT2Source
#   name       : 'salt2-extended'
#   version    : 1.0
#   phases     : [-20, .., 50] days
#   wavelengths: [300, .., 18000] Angstroms
# effect (name='host' frame='rest'):
#   class           : CCM89Dust
#   wavelength range: [909.09, 33333.3] Angstroms
# effect (name='mw' frame='obs'):
#   class           : CCM89Dust
#   wavelength range: [909.09, 33333.3] Angstroms
# parameters:
#   z       = 0.29999999999999999
#   t0      = 49370.0
#   x0      = 2.55194197621852e-05
#   x1      = 0.5
#   c       = 0.10000000000000001
#   hostebv = 0.050000000000000003
#   hostr_v = 3.1000000000000001
#   mwebv   = 0.0
#   mwr_v   = 3.1000000000000001

# %%
for keys in obstables2:
    # Manipulate Obstable to form we can use for SNCosmo realize_lcs
    # Should make a function using this for future
    col = Table.Column(obstables2[keys]['SEARCH'].size*['ab'], name='zpsys')
    obstables2[keys]['FLT'].name =  'band'
    obstables2[keys]['MJD'].name =  'time'
    obstables2[keys]['ZPTAVG'].name =  'zp'
    obstables2[keys]['CCD_GAIN'].name =  'gain'
    obstables2[keys]['SKYSIG'].name =  'skynoise'
    obstables2[keys].add_column(col)
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# <ipython-input-1-ad36dffaa62a> in <module>()
# ----> 1 for keys in obstables2:
#       2     # Manipulate Obstable to form we can use for SNCosmo realize_lcs
#       3     # Should make a function using this for future
#       4     col = Table.Column(obstables2[keys]['SEARCH'].size*['ab'], name='zpsys')
#       5     obstables2[keys]['FLT'].name =  'band'
#
# NameError: name 'obstables2' is not defined

# %%
light_curves = {}

for keys in obstables2:
    lc_id = 'LC' + str(keys)
    print lc_id
    obstable_temp = sncosmo.realize_lcs(obstables2[keys], model_noext, [params_noext], trim_observations=True)
    light_curves[lc_id] = obstable_temp[0]
    
#for keys in light_curves:
#    sncosmo.write_lc(light_curves[keys], str(keys) + '.dat')
#    print str(keys) + '.dat'
# Out:
# LC519
# LC1427

# %%
light_curves['LC519']
# Out:
# <Table masked=False length=453>
#     time      band        flux        fluxerr       zp    zpsys
#   float64   string48    float64       float64    float64 string16
# ----------- -------- ------------- ------------- ------- --------
# 49353.13317   lsst_g 35352.2628795 320.532941433   35.34       ab
# 49353.17576   lsst_g 17301.0067307 237.392993556   34.57       ab
# 49353.12388   lsst_r 51571.7063491 314.813139012   35.17       ab
# 49353.16647   lsst_r 52138.2730167  320.41720551   35.16       ab
# 49353.11458   lsst_i 38730.4129414 300.447722722   34.85       ab
# 49353.15718   lsst_i 39750.3449926 306.417226651   34.86       ab
# 49353.14788   lsst_z 28750.9785232 283.361715301   34.47       ab
# 49353.14252   lsst_Y 4997.82456422 187.943853952    32.8       ab
# 49354.13317   lsst_g 48568.1663073 302.051377836   35.33       ab
# 49354.17576   lsst_g 23945.1403082 224.775531794   34.56       ab
#         ...      ...           ...           ...     ...      ...
# 49433.14788   lsst_z 16964.4415241 317.326662141   34.35       ab
# 49433.14252   lsst_Y 3103.16962605 208.741574453   32.37       ab
# 49434.13317   lsst_g  4495.3956997 275.523713912   34.98       ab
# 49434.17576   lsst_g 1798.66521233  187.15013687   33.96       ab
# 49434.12388   lsst_r 16011.6986547 275.891835743   34.99       ab
# 49434.16647   lsst_r 14316.2312228 286.039174568   34.86       ab
# 49434.11458   lsst_i 26344.9164036 317.121809816   34.75       ab
# 49434.15718   lsst_i 24462.4976058 332.271453971   34.65       ab
# 49434.14788   lsst_z 16822.1714282 330.629229401   34.37       ab
# 49434.14252   lsst_Y 2494.21324914  210.25541334   32.37       ab

# %%
LC_instances = {}
for keys in light_curves:
    LC_instances['test' + str(keys)] = lc.LC(model_noext, vparams=vparams, data=light_curves[keys])
    
LC_instances
# Out:
# {'testLC1427': <lc.LC at 0x10944add0>, 'testLC519': <lc.LC at 0x10944ae50>}

# %%
LC_instances['testLC1427'].plotLC()

# %%
def test_run():
    for keys in LC_instances:
        LC_instances[keys].fitOut

# %%
% time test_run()

# %%
# check this worked
LC_instances['testLC1427'].fitOut

# %%
def test_mcmc():
    for keys in LC_instances:
        LC_instances[keys].mcmcOut

# %%
% time test_mcmc()

# %%
# check this worked
LC_instances['testLC1427'].mcmcOut

# %%
def test_nest():
    for keys in LC_instances:
        LC_instances[keys].nestOut

# %%
% time test_nest()

# %%
# check this worked
LC_instances['testLC519'].nestOut

# %%
for keys in LC_instances:
    id = keys[4:]
    LC_instances[keys].writeFits('looptest.hdf5', id)

# %%
io_dict = {}

for keys in LC_instances:
    id = keys[4:]
    print id
    io_dict['io' + keys] = lc.LC(model_noext, vparams=vparams, data=light_curves[id])
    
print io_dict
# Out:
# LC519
# LC1427
# {'iotestLC519': <lc.LC object at 0x10e1b1610>, 'iotestLC1427': <lc.LC object at 0x10944af90>}

# %%
for keys in io_dict:
    id = keys[6:]
    io_dict[keys].fitOut, io_dict[keys].mcmcOut, io_dict[keys].nestOut = io_dict[keys].readFits('looptest.hdf5', id)
    print id
    print keys
# Out:
# LC519
# iotestLC519
# LC1427
# iotestLC1427

# %%
#check this worked
for keys in io_dict:
    print io_dict[keys].fitModel
    #print io_dict[keys].mcmcOut
    #print io_dict[keys].nestOut
# Out:
# <Model at 0x10ddae4d0>
# source:
#   class      : SALT2Source
#   name       : 'salt2-extended'
#   version    : 1.0
#   phases     : [-20, .., 50] days
#   wavelengths: [300, .., 18000] Angstroms
# parameters:
#   z  = 0.29999999999999999
#   t0 = 49369.997109222706
#   x0 = 2.5527590231568317e-05
#   x1 = 0.49830771868382984
#   c  = 0.10012200477042532
# <Model at 0x10ddca690>
# source:
#   class      : SALT2Source
#   name       : 'salt2-extended'
#   version    : 1.0
#   phases     : [-20, .., 50] days
#   wavelengths: [300, .., 18000] Angstroms
# parameters:
#   z  = 0.29999999999999999
#   t0 = 49369.998002869514
#   x0 = 2.5532483054626049e-05
#   x1 = 0.49581791683165966
#   c  = 0.099823458480866101

# %%
for keys in io_dict:
      io_dict[keys].plotLC()

# %%
for keys in io_dict:
      io_dict[keys].plotCorner()

# %%
for keys in io_dict:
      io_dict[keys].plotTrace()

# %% [markdown]
# fits don't track $x_0$ well
# how to add time variable for clock function
# distance modulus definition
# mactex distribution not working?
# how does sncosmo calculate covariance matrix
# $P_1 =1$ ?

# %% [markdown]
# conditional statement
# read screen input
# model source from sncosmo
# color='k'
# run sncosmo.chi2 on other fits
# sometime run with modelcov=True
# concatenate ex 'MLE_' + snid

# %% [markdown]
# compared simulated_lc.dat results from just sncosmo and with LC class
# add Gaussian result from fit_lc to the corner plots

# %%
io_dict['iotestLC1427'].fitOut = None

# %%
io_dict['iotestLC1427'].rerunFits()
# Out:
# fit_lc() output reran
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# <ipython-input-39-c488e1f7b28f> in <module>()
# ----> 1 io_dict['iotestLC1427'].rerunFits()
#
# /Users/lisaleemcb/sncosmo_lc_analysis/lc.py in rerunFits(self)
#     149         if not self.fitRes:
#     150             print "fit_lc() output reran"
# --> 151             self.fitRes = self._fitOut[0]
#     152             self.fitModel = self._fitOut[1]
#     153
#
# TypeError: 'NoneType' object has no attribute '__getitem__'
