# %%
# %matplotlib inline

import os
import numpy as np
from numpy.random import normal, uniform
import collections
import pandas as pd
from astropy.table import Table

import triangle
import sncosmo
import simulate_lsst as sl
import lightcurve_analysis as lca

# %%
data = sncosmo.read_lc('sn.dat')

# %%
model = sncosmo.Model(source='salt2-extended')
params = {'t0': data.meta['SIM_PEAKMJD'], 'x0': data.meta['SIM_SALT2x0'],
          'x1': data.meta['SIM_SALT2x1'], 'c': data.meta['SIM_SALT2c'],
          'z': data.meta['SIM_REDSHIFT_HELIO']}
model.set(**params)
vparams = ['t0', 'x0', 'x1', 'c']

# %% [markdown]
# The class has now been renamed <code>lightcurve_analysis</code> (imported as <code>lca</code> for compactness).  The class object(?) is now called <code>LCA</code>.
#
# You can initiate an instance of the class as below:

# %%
example = lca.LCA(data, model, vparams)
example.model

# %%
example.fit_out
# Out:
# running chi^2 fit
# (       errors: OrderedDict([('t0', 0.869705464632716), ('x0', 6.352280833289825e-08), ('x1', 0.5247654629885447), ('c', 0.048283506458290146)])
#    parameters: array([  1.06371000e+00,   5.09155364e+04,   1.19022208e-06,
#         -1.37443229e+00,  -2.74520718e-02])
#       success: True
#          ndof: 79
#    covariance: array([[  7.56396247e-01,  -1.47415535e-08,   9.27513342e-02,
#           8.97227286e-03],
#        [ -1.47415535e-08,   4.03514718e-15,  -1.57647791e-08,
#           8.09694619e-10],
#        [  9.27513342e-02,  -1.57647791e-08,   2.79008873e-01,
#           1.00106837e-02],
#        [  8.97227286e-03,   8.09694619e-10,   1.00106837e-02,
#           2.35188405e-03]])
#  vparam_names: ['t0', 'x0', 'x1', 'c']
#         chisq: 94.67428083189289
#   param_names: ['z', 't0', 'x0', 'x1', 'c']
#       message: 'Minimization exited successfully.'
#         ncall: 98,
#  <sncosmo.models.Model at 0x103d585d0>)

# %%
example.mcmc_out
# Out:
# running MCMC fit
# (             vparam_names: ['t0', 'x0', 'x1', 'c']
#                    errors: OrderedDict([('t0', 0.92944787113652294), ('x0', 6.1700313156858631e-08), ('x1', 0.55788357083772055), ('c', 0.050313000933750129)])
#                   samples: array([[  5.09142987e+04,   1.23108303e-06,  -2.02831222e+00,
#          -5.65214180e-02],
#        [  5.09142987e+04,   1.23108303e-06,  -2.02831222e+00,
#          -5.65214180e-02],
#        [  5.09142987e+04,   1.23108303e-06,  -2.02831222e+00,
#          -5.65214180e-02],
#        ...,
#        [  5.09159629e+04,   1.16804999e-06,  -8.71660618e-01,
#          -3.27191958e-02],
#        [  5.09171663e+04,   1.22993679e-06,  -1.50513124e+00,
#          -4.00715480e-02],
#        [  5.09169233e+04,   1.22845994e-06,  -1.53161916e+00,
#          -4.25449965e-02]])
#                parameters: array([  1.06371000e+00,   5.09156016e+04,   1.18526133e-06,
#         -1.26410634e+00,  -1.60112198e-02])
#               param_names: ['z', 't0', 'x0', 'x1', 'c']
#  mean_acceptance_fraction: 0.59430000000000005
#                covariance: array([[  8.63873345e-01,  -1.33263853e-08,   1.20806427e-01,
#           1.11459206e-02],
#        [ -1.33263853e-08,   3.80692864e-15,  -1.68739104e-08,
#           7.76453768e-10],
#        [  1.20806427e-01,  -1.68739104e-08,   3.11234079e-01,
#           1.15651283e-02],
#        [  1.11459206e-02,   7.76453768e-10,   1.15651283e-02,
#           2.53139806e-03]]),
#  <sncosmo.models.Model at 0x1105f4a50>)

# %%
example.write_fits('example_fits.hdf5', 'example')

# %%
example.reset_all()

# %%
example.fit_out, example.mcmc_out = example.read_fits('example_fits.hdf5', 'example')
# Out:
# ---------------------------------------------------------------------------
# UnboundLocalError                         Traceback (most recent call last)
# <ipython-input-9-89035bb06dd9> in <module>()
# ----> 1 example.fit_out, example.mcmc_out = example.read_fits('example_fits.hdf5', 'example')
#
# /Users/lisaleemcb/sncosmo_lc_analysis/lightcurve_analysis.py in read_fits(self, filename, id)
#     262
#     263         fit_model_params = {}
# --> 264         for number in count:
#     265             fit_model_params[fit_result.param_names[number]] = fit_result.parameters[number]
#     266
#
# UnboundLocalError: local variable 'count' referenced before assignment

# %%
lc_fig = example.plot_lightcurves()

# %% [markdown]
# ### New Functionality

# %% [markdown]
# <code>resetAll</code>

# %% [markdown]
# You can set all the fits to <code>Type None</code>.
#
# Example:

# %%
example.reset_all()

# %% [markdown]
# check this:

# %%
example.fit_out
# Out:
# running chi^2 fit
# (       errors: OrderedDict([('t0', 0.869705464632716), ('x0', 6.352280833289825e-08), ('x1', 0.5247654629885447), ('c', 0.048283506458290146)])
#    parameters: array([  1.06371000e+00,   5.09155364e+04,   1.19022208e-06,
#         -1.37443229e+00,  -2.74520718e-02])
#       success: True
#          ndof: 79
#    covariance: array([[  7.56396247e-01,  -1.47415535e-08,   9.27513342e-02,
#           8.97227286e-03],
#        [ -1.47415535e-08,   4.03514718e-15,  -1.57647791e-08,
#           8.09694619e-10],
#        [  9.27513342e-02,  -1.57647791e-08,   2.79008873e-01,
#           1.00106837e-02],
#        [  8.97227286e-03,   8.09694619e-10,   1.00106837e-02,
#           2.35188405e-03]])
#  vparam_names: ['t0', 'x0', 'x1', 'c']
#         chisq: 94.67428083189289
#   param_names: ['z', 't0', 'x0', 'x1', 'c']
#       message: 'Minimization exited successfully.'
#         ncall: 98,
#  <sncosmo.models.Model at 0x10fe26710>)

# %%
example.mcmc_out
# Out:
# running MCMC fit
# (             vparam_names: ['t0', 'x0', 'x1', 'c']
#                    errors: OrderedDict([('t0', 0.86415747458208214), ('x0', 6.4979329740936345e-08), ('x1', 0.52752096927410086), ('c', 0.04748245600139421)])
#                   samples: array([[  5.09154020e+04,   1.18283140e-06,  -1.33620518e+00,
#          -4.29486178e-02],
#        [  5.09153764e+04,   1.15806006e-06,  -1.21624898e+00,
#          -5.67048712e-02],
#        [  5.09153899e+04,   1.15886616e-06,  -1.21180370e+00,
#          -5.45828402e-02],
#        ...,
#        [  5.09143810e+04,   1.27381592e-06,  -1.32405003e+00,
#          -2.18038358e-02],
#        [  5.09143810e+04,   1.27381592e-06,  -1.32405003e+00,
#          -2.18038358e-02],
#        [  5.09146407e+04,   1.25820685e-06,  -1.28701456e+00,
#          -1.35235341e-02]])
#                parameters: array([  1.06371000e+00,   5.09156998e+04,   1.18172251e-06,
#         -1.28015460e+00,  -2.10679345e-02])
#               param_names: ['z', 't0', 'x0', 'x1', 'c']
#  mean_acceptance_fraction: 0.58929999999999993
#                covariance: array([[  7.46768141e-01,  -1.32925288e-08,   1.19807442e-01,
#           1.00419038e-02],
#        [ -1.32925288e-08,   4.22231329e-15,  -1.66245938e-08,
#           6.97532964e-10],
#        [  1.19807442e-01,  -1.66245938e-08,   2.78278373e-01,
#           9.61103853e-03],
#        [  1.00419038e-02,   6.97532964e-10,   9.61103853e-03,
#           2.25458363e-03]]),
#  <sncosmo.models.Model at 0x1103b5750>)

# %% [markdown]
# <code>plot_corner</code>

# %%
corner_fig = example.plot_corner()

# %% [markdown]
# <code>rerunFits</code>

# %%
import math
import matplotlib.pyplot as plt
import matplotlib.mlab as mlab

# %%
mean = example.fit_res.parameters[1]
variance = example.fit_res.covariance[0][0]
sigma = math.sqrt(variance)
min = example.fit_res.parameters[1] - 8*sigma
max = example.fit_res.parameters[1] + 8*sigma
x = np.linspace(min, max, 100)

# %%
axes = testG.axes
axes[0].hist(example.mcmc_res.samples[:,0], bins=20, normed=True)
axes[0].plot(x,mlab.normpdf(x,mean,1))

# %%
testG
